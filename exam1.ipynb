# %%
import sys
print(sys.version)

# %%
import os
print(os.getcwd())

# %%
# !jupyter kernelspec list

# %%
# !dir

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print(res.version)
print(res.msg)
res_header = res.getheaders()
print("[ header 정보 ]----------")
for s in res_header :
    print(s)

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res)
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
#print(res.read()) # 바이트 문자열, 바이트열 - b'..............'
print(res.read().decode('utf-8'))

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'https://www.daum.net/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset() 
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'http://www.yes24.com/Main/default.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
encoding = 'utf-8' if encoding == None else encoding
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

# %%
from urllib.parse import urlparse
from urllib.parse import urlencode
print("[ URL 문자열 정보 추출 1 ]")
url1 = urlparse('https://movie.daum.net/moviedb/main?movieId=93252')
print("타입정보 : ",type(url1))
print("도메인정보 : ",url1.netloc) 
print("패스정보 : ",url1.path)
print("쿼리정보 : ",url1.query) 
print("스킴정보 : ",url1.scheme)
print("포트정보 : ",url1.port)
print("프래그먼트정보 : ",url1.fragment)
print("URL 문자열정보 : ",url1.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url1)
print("\n[ URL 문자열 정보 추출 2 ]")
url2 = urlparse('https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object')
print("도메인정보 : ",url2.netloc) 
print("패스정보 : ", url2.path)  
print("쿼리정보 : ",url2.query)
print("스킴정보 : ",url2.scheme)
print("포트정보 : ",url2.port)
print("프래그먼트정보 : ",url2.fragment)
print("URL 문자열정보 : ",url2.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url2)

print("\n[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8'))

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.head('http://unico2013.dothome.co.kr/crawling/exam.html')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

dicdata = {'key1': 'value1', 'key2': 'value2'}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content))
print(type(i))
i.save("c:/Temp/test.jpg")

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Test BeautifulSoup
#   </title>
#  </head>
#  <body>
#   <p align="center">
#    P태그의 컨텐트
#   </p>
#   <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
#  </body>
# </html>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'dict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[[[ string 속성 ]]]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[[[ text 속성 ]]]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[[[ contents 속성 ]]]")
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
print("[[[ find_all()의 text=True 매개변수 ]]]")
print(bs.find_all("li", text=True))  # 콘텐츠가 텍스트로만 구성된
# Out:
# [[[ string 속성 ]]]
# <class 'bs4.element.NavigableString'> : P태그의 컨텐트
# <class 'NoneType'> : None
# <class 'NoneType'> : None
# <class 'bs4.element.NavigableString'> : 강조
# [[[ text 속성 ]]]
# <class 'str'> : P태그의 컨텐트
# <class 'str'> :
# 테스트1강조
# 테스트2
# 테스트3
#
# <class 'str'> : 테스트1강조
# <class 'str'> : 강조
# [[[ contents 속성 ]]]
# <class 'list'> : ['P태그의 컨텐트']
# <class 'list'> : ['\n', <li>테스트1<strong>강조</strong></li>, '\n', <li>테스트2</li>, '\n', <li>테스트3</li>, '\n']
# <class 'list'> : ['테스트1', <strong>강조</strong>]
# <class 'list'> : ['강조']
# [[[ find_all()의 text=True 매개변수 ]]]
# [<li>테스트2</li>, <li>테스트3</li>]

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)
# Out:
# <class 'bs4.element.Tag'>
# <class 'bs4.element.ResultSet'>
# ---------------------------------
# <title>Test BeautifulSoup</title>
# <p align="center"> text contents </p>
# <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500"/>
# ---------------------------------
# [<p align="center"> text contents </p>, <p align="right">  text contents 2 </p>, <p align="left">   text contents 3 </p>, <p>text contents 4</p>]
# ----------------
# <p align="center"> text contents </p>
# <p align="right">  text contents 2 </p>
# <p align="left">   text contents 3 </p>
# <p>text contents 4</p>

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")
# Out:
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# -------------------------------------
# <p align="center"> text contents </p>
# <p align="right" class="myp">  text contents 2 </p>
# <p a="b" align="left">   text contents 3 </p>
# [   text contents 3 ]
# [text contents 3]
# [text contents 3]

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
#print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])
# Out:
# <class 'bytes'>
# ==============================
# [<h1>CSS 선택자 학습</h1>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie')
points = soup.select('td.title > div > em')
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6] 
    #content=re.sub("신고", '', content)
    content=re.sub("[\n\t]", '', content)    
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 효자
# 평점 : 10
# 리뷰글 : 사실 크게웃기는장면도 없었지만한번쯤 생각하게만드는 영화였다돌아가신 엄마가생각나서 얼마나울었는지 모른다 꼭한번보면좋은 영화이다
# -----------------------------------------
# 영화 제목 : 야차
# 평점 : 9
# 리뷰글 : 나름대로 볼만했습니다.(평점이 너무 낮아서 8+1=9점)
# -----------------------------------------
# 영화 제목 : 신비한 동물들과 덤블도어의 비밀
# 평점 : 3
# 리뷰글 : ???: 2편을 위한 희생입니다! 3편을 위한 희생입니다! 4편을 위한 희ㅅㅐ....
# -----------------------------------------
# 영화 제목 : 쇼생크 탈출
# 평점 : 10
# 리뷰글 : 가석방 심사위원 앞 남자의 말들이 내 가슴속 말 같아서 눈물을 펑펑 흘렸다 그렇게까지 울 포인트가 전혀 아니었으나 눈물이 쏟아졌다 연기와 연출과 스토리에 감사를 보낸다 명화였다…
# -----------------------------------------
# 영화 제목 : 비밀은 없다
# 평점 : 10
# 리뷰글 : 아주 생각보다 잼났음. 손예진 연기대박이긴 하네.
# -----------------------------------------
# 영화 제목 : 야차
# 평점 : 1
# 리뷰글 : 그 놈의 정치영화...
# -----------------------------------------
# 영화 제목 : 뜨거운 피
# 평점 : 9
# 리뷰글 : 깡패영화만 챙겨보는 전문가로써 꽤 괜찮은 영화.
# -----------------------------------------
# 영화 제목 : 나이트메어 앨리
# 평점 : 10
# 리뷰글 : 세명의 아버지를 죽인 피의 댓가
# -----------------------------------------
# 영화 제목 : 이상한 나라의 수학자
# 평점 : 9
# 리뷰글 : 학교라는 작은 장소 안에서 다양한 스토리를 함축해서 풀어낸 영화네요몰입도 좋았고 전체적으로 재밌게 봤습니다
# -----------------------------------------
# 영화 제목 : 신비한 동물들과 덤블도어의 비밀
# 평점 : 7
# 리뷰글 : 4,5편이 궁금해지는 작품이네....
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31):
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 10,테일 오브 테일즈,판타지 동화장르가 뭔지 제대로 눈으로 보여주는 영화였다.
# 10,신비한 동물들과 덤블도어의 비밀,해리포터 매니아라면 그냥 다 재미있는 이야기. ^^평점 보고 기대 안했는데 완전 잼나게 봤네요.
# 9,바이크 솔저,이놈들이 별 댓글도 아니면서 스포일러 있음으로  글 숨기고 멋부리네 고얀 놈들
# 6,이상한 나라의 수학자,뒤로갈수록 여인의 향기와 똑같다는 느낌을 받네요. 음..
# 10,듄,
# 10,야차,일부러 별점테러하는분들 때문에 높게드림
# 2,야차,우린 첩보하지 말자 그라고 시나리오가 발이면 최소한 대놓고 친북은 안해야지
# 10,마지막 게임,평점웨이러지 ;; 끝까지 너무 재밌게 봐서 여운이남는 영화.
# 7,신비한 동물들과 덤블도어의 비밀,귀엽네요 극장에서 볼만합니다. from 추억과 의리로 보는 해리포터팬
# 10,신비한 동물들과 덤블도어의 비밀,전작보다 볼거리가 많아서 좋았어요. 1, 2편 본지 좀 돼서 보기 전에 다시 봤는데 그래서 그런지 몰입도 좀 더 잘 됐고요.
# -----------------------------------------------------
# 2,극장판 주술회전 0,지루하네요~~일본에니가 이전만 못하네
# 8,신비한 동물들과 덤블도어의 비밀,학원 째고 보는 영화라 더 재밌었어요! 이름은 모르는데 얼굴은 익숙한 분들 많이 나오고, 귀여운데 함께 살고싶지는 않은 동물친구들도 많이 나와요. 무슨 내용인지 생각없이 봐도 배우분들 얼굴 구경하고 이상한 막대들고 나라면 현타 씨게 오겠다 싶은 씬들 몇번 지나가면 끝나요.
# 3,서스페리아 1977,1977년도면 그때 당시 너이 제시캬 허퍼가 28세 현재 나이 만 73세 꽤 오래된 영화다 할머니가 되어있겠네
# 8,신비한 동물들과 덤블도어의 비밀,very good story, visuals
# 10,신비한 동물들과 덤블도어의 비밀,4,5 당장 내노ㅏ....나는 죽기전에 꼭 봐야겟으니께존잘 중년 게이들 너무좋다
# 10,이상한 나라의 수학자,수학의 아름다움을 느껴보고싶다…언젠가능
# 10,어린왕자,어린 시절을 잊고살던 어른들에게 동심을 다시 되찾게 해주는 영화
# 10,더 배트맨,리들러와 배트맨의 관계를 재미있게 해석한 영화. 미숙했던 시기와 '세계 최고의 명탐정'이라는 타이틀에 주목한게 신선했습니다.
# 2,앰뷸런스,미치겠다...정말 어디서 재밌다고 해야되나
# 1,듄,원작인 프랭크 허버트의 소설처럼 영화는 지루하다. 1984년작 보다 나은 점은 영상미가 화려하다는 것. 그러나 그 뿐. 한스 짐머의 음악이 아깝다. 영화 내내 무슨 내용인지 무슨 소리인지 잘 모르겠고 왜 침을 연거푸 뱉어대는지 이상하고 칼 싸움씬은 무슨 조폭 영화 보다도 떨어진다. 진짜 지루한 영화는 바로 이런 영화를 두고 한 말일 것이다. 지루한 것 잘 참는 심각한 영화팬용. '에쿠우스'가 그렇다는 말이 있다. 1984년작도 미 영화 가이드에서 빵점을 줬다. 스타워즈4,5에 비하면 듄은 정말 답답한 공상과학 영화이다. 듄이 미 아카데미(오스카)상을 여러 개 받으면 뭐하나...영화 자체가 재미가 없는데...
# -----------------------------------------------------
# 4,야차,cg수준이 이거밖에 안되나.
# 4,신비한 동물들과 덤블도어의 비밀,키포인트가 뭔가요? 왜 제목을 덤블도어의 비밀로 했는지도 모르겠고 스토리 내내 지루했어요그나마 장점은 맥고나걸 교수 젊은적 시절 본것뿐 시간 아까웠어요
# 10,극장판 주술회전 0,지친 하루를 위로해주는 재밌는영화였습니다
# 6,신비한 동물들과 덤블도어의 비밀,진짜 의리로 봤다 뭐 전투가 개좋게 나올꺼같이 광고해놨더만 볼드모트랑 마법부에서 싸운게 더 화려했다 이거 뭔 그냥 수퍼소닉이나 볼껄
# 10,야차,비슷한 내용의 외국영화보다 연기력도 내용도 개연성이고 설득력있는 영화네요.출연자 모두 연기력도 대단하군요.재미있게 잘봤어요.  오랜만에 훌륭한 영화 한편 잘보았어요.야차 홧팅
# 7,신비한 동물들과 덤블도어의 비밀,스토리가 얕다. 간만에 영화보다가 졸아봤다.
# 9,사랑 후의 두 여자,보다가 얼굴도 모르는 두여자의 남편을 계속 욕했다. 진짜 쓰레기놈..!!하지만 남편으 부재로 인해 또다른 가족이 만들어지는 과정은 정말 몰입감 있고 흥미진진하게 봤다. 나였으면을 감정이입하게 됬던 작품
# 10,수퍼 소닉2,소닉 좋아하는 분 꼭 보삼
# 10,날씨의 아이,이번에 재개봉해서 또 봤는데 역시나 또 볼만했다.. 항상 감정을 뒤흔드는 영화
# 10,야차,전 너무 잼있게 봤어요
# -----------------------------------------------------
# 10,레미제라블,너무 재밌게 봤던.. 또 재개봉하면 보러 갈 의향이 충분!
# 7,스케어리 스토리: 어둠의 속삭임,그럭저럭 볼만했던 기억이, 생각보다는 안무서워서 좀..
# 6,클로이,당황시키더니 훅!가네 ;;;
# 10,이클립스,여주 너무한거 아니냐..??
# 6,신비한 동물들과 덤블도어의 비밀,너무영상이어두워서지루해서졸림뭔소린지모르겠네요해리포터랑관련있는건지잘안봐그런가동물사전도.그리재미없더니그냥 예고편을 엄청 잘 만든것같아요
# 8,신비한 동물들과 덤블도어의 비밀,매트릭스2 느낌이 약간 났습니다. 지루한 중반까지의 스토리 이후 결 부분에서는 괜찮은 모습을 보여 줬네요
# 10,스폰지밥 무비: 핑핑이 구출 대작전,재미있게 보았어요 이번에는그래픽이여서 화질이좋네요
# 10,더 배트맨,가면 쓴 복수자가 진정한 십자군으로 바뀌고 상처가 아물면서 흉터로 남는 과정을 고통스럽고 집요하게 묘사하는 스트레스풀한 '변신' 이야기. 특히 배트맨의 내면을 쫓아가는 것이 재미있었습니다. 다만 "수퍼히어로"를 기대하면 지루해지는 영화네요.
# 2,야차,개연성도 부족하고 오글거리고..재미없네요..ㅠ
# 1,야차,억지에 억지를 갖다붙여 억지스럽게 마무리한 영화
# -----------------------------------------------------
# 10,이상한 나라의 수학자,웰 메이드 영화... 코로나 시국만 아녔으면 이리 소리소문 없이 묻히지는 않았을텐데..
# 9,타임 패러독스,자신의 꼬리를 먹는 뱀 처럼
# 10,리얼 스틸,10번 넘게 봄 !!!!
# 7,신비한 동물들과 덤블도어의 비밀,스토리 보다는 동물들보는 소소한 재미로 봤습니다. 볼만했어요~
# 10,극장판 주술회전 0,ㅠㅠ소장하고싶음후유증으로 현생 못사는 중
# 10,테이큰,
# 7,루이스 웨인: 사랑을 그린 고양이 화가,
# 1,야차,북한을 일본으로 바꾸는 기적의 선전선동 영화 반일선동 코인도 안통한 불후의 명작
# 7,나, 다니엘 블레이크,흠~그냥 저냥 시간떼우기로 볼만함
# 10,그것만이 내 세상,
# -----------------------------------------------------
# 10,해리 포터와 마법사의 돌,다시는 없을 것 같은 영화
# 1,신비한 동물들과 덤블도어의 비밀,구데기 그 자체....
# 10,신비한 동물들과 덤블도어의 비밀,평점이 왜이렇게 낮은지 모르겠어요..아마 해리포터 내용을 몰라서 낮은게 아닌지.. 덕후의 입장에서는 재미있었어요.
# 6,야차,보다가 딴생각하게 만드는 영화클라이막스 격투씬이 제일 별로...대사가 진부하고 상투적주인공들의 부로맨스 결여
# 10,야차,나름대로 괜찮았습니다.
# 1,컨택트,영화 속 등장인물들이 뭐하고 있는 건지 보고 있자니 잠이 계속 밀려와서 힘들었다
# 6,인민을 위해 복무하라,스토리 연기력이 아쉽네요
# 9,뜨거운 피,배우들 연기 좋네요
# 1,더 배트맨,역대 배트맨 중에 가장 개노잼
# 10,노바디 ,아 ㅅㅂ 끝내주네! 세기말 컬트!
# -----------------------------------------------------
# 6,앰뷸런스,늦잠자서 예매하고 못봄 짜증나
# 1,종말의 끝,장난치나 ㅋㅋㅋㅋ 결말 머임
# 10,이상한 나라의 수학자,
# 9,이상한 나라의 수학자,이렇게 스토리와 영상미가 풍부한 영화의 관객이 겨우 50만명이 조금 넘는다는 현실이 믿기지 않는다. 꼭 한번 보기를 추천할 만한 영화이다.
# 1,분노의 질주: 더 얼티메이트,ost 신나네요 노래듣고 꿀잠도 잤어요
# 10,색, 계,신이주신 이성간의 사랑은...눈으로 말하는 것. 그리고 몸으로 말하는 것. 구구절절 조건따지는 대다수 인간군상은 사랑다운 사랑한번 못하고  세상살다 가겠지
# 10,신비한 동물들과 덤블도어의 비밀,덤블도어의 비밀이 조금씩 밝혀지기 시작함
# 9,모비우스,전투신을 너무 클로즈업하여 눈이 어지러운 신이 있었음. 그래도 스토리는 개인적으로 맘에 듬. 후속작이 기대가 됨.
# 9,이상한 나라의 수학자,마지막은 갑자기 스토리 개연성이 떨어졌지만중후반부 까지는 굉장히 잘 만든 영화라는 생각이 들었다마지막만 아니라면 한번더 극장에서 보고 싶은 영화였다
# 10,판의 미로 - 오필리아와 세 개의 열쇠,너무 슬픈 영화... 소녀의 영원한 도피처는 죽음이었어
# -----------------------------------------------------
# 10,거북이 달린다,
# 1,신비한 동물사전,재밌겟지하고 계속 기다리다가 결국....끝남
# 10,달빛궁궐,일단  잼있네요! ! 이거 추천합니다압!!
# 1,신비한 동물들과 덤블도어의 비밀,OOO기 보다가 나옴 쓋
# 10,효자,사실 크게웃기는장면도 없었지만한번쯤 생각하게만드는 영화였다돌아가신 엄마가생각나서 얼마나울었는지 모른다 꼭한번보면좋은 영화이다
# 9,야차,나름대로 볼만했습니다.(평점이 너무 낮아서 8+1=9점)
# 3,신비한 동물들과 덤블도어의 비밀,???: 2편을 위한 희생입니다! 3편을 위한 희생입니다! 4편을 위한 희ㅅㅐ....
# 10,쇼생크 탈출,가석방 심사위원 앞 남자의 말들이 내 가슴속 말 같아서 눈물을 펑펑 흘렸다 그렇게까지 울 포인트가 전혀 아니었으나 눈물이 쏟아졌다 연기와 연출과 스토리에 감사를 보낸다 명화였다…
# 10,비밀은 없다,아주 생각보다 잼났음. 손예진 연기대박이긴 하네.
# 1,야차,그 놈의 정치영화...
# -----------------------------------------------------
# 9,뜨거운 피,깡패영화만 챙겨보는 전문가로써 꽤 괜찮은 영화.
# 10,나이트메어 앨리,세명의 아버지를 죽인 피의 댓가
# 9,이상한 나라의 수학자,학교라는 작은 장소 안에서 다양한 스토리를 함축해서 풀어낸 영화네요몰입도 좋았고 전체적으로 재밌게 봤습니다
# 7,신비한 동물들과 덤블도어의 비밀,4,5편이 궁금해지는 작품이네....
# 8,코다,깊은 간접체험을 할 수 있었다
# 7,성실한 나라의 앨리스,왜 이 영화를 몰랐었지? ;;;
# 6,슈퍼 에이트,외계인이 온건 확실한데, 도대체 무슨 목적인거냐?
# 10,언브레이커블,8.5가 적당해보여, 평균 맞추고자 10점... 다크나이트 시리즈의 프리퀄을 본 것 같은 느낌...
# 5,설국열차,뭐 어떻게 흘러가는지 모르겠다
# 2,신비한 동물들과 그린델왈드의 범죄,해리포터 후속작 맞나? 진짜 노오잼 입니다..
# -----------------------------------------------------
# 10,위대한 쇼맨,이제야 보다니 영화관에서 다시 보고싶네요~
# 10,야차,한국 배우들은 연기를 워낙 잘하니 보는 맛도 있고 재미있어서 킬링타임용으로 나쁘지 않음 그런데 여기에 있는 심한 악플들은 왜 다는지 이해가 안가네
# 10,버닝,전 영화한편다보는데 굉장히 집중하지못하고 산만한편인데 이건 너므 흥미로웠어요
# 10,이상한 나라의 수학자,간나새끼마음과 마음이 상처와 상처가 만나는 곳!
# 1,델마와 루이스,개연성 개떨어지고 빡대가리 두명이 저지르는 좌충우돌 개 같은 영화
# 8,킹 리차드,연기 잘함
# 10,너를 보내는 숲,
# 10,신비한 동물들과 덤블도어의 비밀,2편보다 정돈된 느낌 재밌었음!
# 8,라스트 듀얼: 최후의 결투,결투장면 연출이 전부이고 압권
# 9,은밀하게 위대하게,생각보다 재밌었음~~
# -----------------------------------------------------
# 10,O2,초반부엔 영화 '베리드'가 생각나게 했고 후반부로 갈수록 신선하고 재밌는 SF소재의 영화란걸 보여줬다.. 멜라니 로랑의 연기도 좋았다..^^
# 8,뜨거운 피,배우들 연기짱. 스토리도 만족. 반전도 만족. 예전에 본 친구 보다는 좋은데요
# 8,야차,아무생각 없이 보기엔 너무 재밌음
# 8,스펜서,IT'S NOT JUST ME WHO LOVES YOU!
# 1,신비한 동물들과 덤블도어의 비밀,ㄹㅇ재미없음1 2 편보고 3편봐야지 했다가큰코다침
# 8,킹 리차드,계획 없는 삶엔 실패만 있을 뿐(If you fail to plan, you plan to fail)
# 1,신비한 동물들과 덤블도어의 비밀,재미, 스토리, 영상미 뭐 하나 제대로 잡은게 없네요. 해리포터 후광으로 돈 벌려고 만든듯한 영화입니다. 1은 정말 재미있게 봤습니다만... 씁쓸하네요 이렇게 재미가 없더라도 해리포터 덕후들은 어쩔 수 없이 봐야하는 이 슬픔...
# 9,루이스 웨인: 사랑을 그린 고양이 화가,당신은 프리즘이야. 프리즘을 통해 삶의 빛을 다양한 색으로 보여주는 사람
# 8,신비한 동물들과 덤블도어의 비밀,어른들을 위한 동화 같습니다. 저는 괜찮았어요.
# 7,미녀 삼총사 3,크리스틴이 진짜 쏘 섹시섹시
# -----------------------------------------------------
# 8,모비우스,2나오면 볼거같긴함 ㅎㅎ 주인공 너무 잘생김
# 1,야차,와. 진짜 더럽게 재미없음이런 쓰레기를 만들다니 감독 진짜 재능없음 인과성 전혀 없고 진부하고 뻔한 스토리 초딩들도 하품할 정도일부러 재미없게 만들라 해도 이보다는 나을 듯 진짜 미친 듯이 재미없음
# 8,신비한 동물들과 덤블도어의 비밀,생각보단 괜찮았음 4편이 나오게될지 의문이지만,,
# 10,포화속의 우정,배우들 인물 진짜 끝내주게 잘 생겼다
# 2,신비한 동물들과 덤블도어의 비밀,사실 정말 재미없습니다. 최악입니다. 뭘 말하는지 뭘할려는지 모르겟고마지막장면 억지
# 8,야차,오바스럽고 뻔한스토리이긴한데 생각보다 잼있는데 나름 엔딩도 무난하고 평점7.5점이 적당하다생각됨
# 1,신비한 동물들과 덤블도어의 비밀,별점 0점은 없나?뭔 스토리가 개연성은 하나도 없고 유치해서 보다 나오고 싶었네요여친이랑 봤는데 둘이 콜콜 자다 나옴
# 1,스텔라,어떤 욕을 해야 앞으로 이런영화를 안내놓을까요
# 8,미안해요, 리키,잘하려고 부단히 노력하는데 잘안되는 사람들..때론 보이는 걸 외면해 버릴때가 있다.. 모른척 눈을 질끈 감는게 속편할때가 있다, 그렇게 외면해버린 낭떠리지에 누군가 위태롭게 있는건 아닌지 뒤돌아보라고 말해주는 영화같다.. 마음은 무겁지만 그래도 의미있는 시간이었다..
# 6,신비한 동물들과 덤블도어의 비밀,해리포터 팬으로 난 재밌었는데...무엇보다 제이콥이 나와서 좋았음.
# -----------------------------------------------------
# 7,티탄,결핍을 채우는 방법. 기괴한 연출에 놀랍다.
# 5,클로젯,스토리는 쏘쏘김남길보는 맛으로 봤다. cg 도 이정도면 나쁘진 않은편
# 2,신비한 동물들과 그린델왈드의 범죄,신비한 동물은 신선한 cg보는맛에 보는건데 그런것도 없고..시종일관 지루하다
# 4,버닝,이해가 안 되는 부분들이 너무 많아서 보는 내내 답답했어요. 특히 오랜만에 만난 친구를 집으로 불러들여서...또 스토커 같이 구는 장면들  작가의 의도가 일반적이지 않은 생각을 하는, 자신만의 세계에 빠져사는 사람들을 보여주고 싶었던 건가요?
# 8,소공녀,노력과 재능없는 사람의 자기합리화를 보여준 것 인지 아니면 순수하게 본인에게 솔직한 사람의 진정성 있는 삶을 표현한 것인지..마음만 편하고 주변에 폐끼칠 사람만 없다면 이렇게 무책임하게 살아도 되냐고 물어본다면 단연코 아니라고 생각하지만 그럼에도 주인공이 가진 자유로움은 부럽고 가치있다고 느끼는게 참 아이러니하네요..
# 3,매트릭스: 리저렉션,매트릭스 찐팬을 위한 영화
# 7,이상한 나라의 수학자,과정이 중요하고 결과는 증명하면 된다. 결말이 아쉽지만 슴슴하니 볼만했음.
# 4,왕립우주군 - 오네아미스의 날개,오타구들이만든 집대성같은영화
# 5,특송,카체이싱 액션 볼만 했어요.
# 7,고교 우량아,중후반부들어와야 이영화의내용이나온다 전편보다는 낫다
# -----------------------------------------------------
# 10,아저씨,진짜 너무 멋있어요 원빈
# 6,하우스 오브 구찌,욕망을 향해 달려가는 레이디 가가의 연기에 빠져든다
# 10,노바디 ,간만에 정말 재밌는 액션영화 기발한 유머에 세번째 봄
# 6,고교 얄개,재미는있고 감동도있다 외국인교장이 하드캐리함
# 8,야차,평점 7~8점은 되주는 스토리와 영상미인데.왜들 이렇게 댓글에 성질들을 부리나????팝콘들고 휴일이나 쉬는시간에 그냥 볼만함.
# 4,더 배트맨,왜 요즘 영화들은 이렇게 칙칙하게 만드는지 모르겠다 이딴게 작품성이라 생각하는 건가?
# 4,더 배트맨,왜 요즘 영화들은 이렇게 칙칙하게 만드는지 모르겠다 이딴게 작품성이라 생각하는 건가?
# 4,신비한 동물들과 덤블도어의 비밀,보다가 지루해서 잠들었어요 ㅠ
# 4,웨스트 사이드 스토리,감독님 어디가셨나요...? 저는 잘 모르겠어요.
# 8,어나더 라운드,적당한 음주로 삶의 활력을 찾을 수 있을까?
# -----------------------------------------------------
# 6,램,원한 건 그저 단란한 가족의 행복이었는데...
# 8,신비한 동물들과 덤블도어의 비밀,나쁘진않았어옹 2가워낙별로여서
# 6,킹메이커,빛과 그림자 연출이 아름답다
# 6,그리스도 디 오리진,천주교 영화네요...
# 6,원 세컨드,영원히 기억 될 1초.
# 8,스파이더맨: 노 웨이 홈,홀로서는 스파이더맨 너의 앞날을 응원한다
# 10,이상한 나라의 수학자,재미있게 보았습니다 간만에
# 10,걷기왕,만복이의 모든 앞날을 응원해
# 10,맘마미아!,1편이 왜히트 했는지 알겠고 최근에 1~2편 연속으로봤는데 아주 잼있게 잘봤어요~
# 2,야차,그냥 좌파 끝발영화. 공안들 총으로 때려잡고 일본대사관 폭파시켜서 들어가는 말도안되는 좌파영화. 일본죽창으로 찔러죽이자는 누가 생각나네요
# -----------------------------------------------------
# 10,포드 V 페라리,
# 2,야차,좌향감독의 뻔한 스토리. 반일 영화를 언제까지 우려 먹을래?
# 10,맘마미아!2,1편과 이어지는 내용 이어서 보면 더 잼있어요~
# 7,청춘적니,현실에 치이는 청춘의 멜로
# 10,그리스도 디 오리진,성경을 통해 알고 있던 내용이지만 다시봐도 감동입니다.
# 10,스파이더맨: 노 웨이 홈,너무 나도 감동스런 영화 였고모든 스파덤더맨이 누군가의 죽음이 일어난다는 것을 알수있었고삼스파가 모였을 때 진짜 감동했다 내 인생 영화이다
# 6,신비한 동물들과 덤블도어의 비밀,그냥저냥 무난한데 매즈 미켈슨은 너무 좋았음
# 10,이상한 나라의 수학자,역시 최민식!! 식상하지 않고 좋았어요
# 3,해적: 도깨비 깃발,좋은 상영관에서보면, 해상전투씬에서 압도감을 받을 수 있음..
# 10,황산벌,영화계 역사에 전설이 된 그 영화
# -----------------------------------------------------
# 10,도둑들,난 티비에서 걍 할때마다 봐서 15번 이상 본거같은데볼때마다 재밋던데...
# 3,나일 강의 죽음,이집트 풍경이 보기 좋네요. 그외 다 그냥그냥
# 10,야차,평점 믿지마라 충분히 즐길수있는 영화다
# 6,굿 보스,그를 굿 보스라 할 수 있는가?
# 9,머니볼,야구 소재 영화인데 야구경기가 메인은 아니다. 야구경기가 메인은 아니지만 야구를 잘아는 사람이라면 훨씬 흥미로울 것이다. 장르 혹은 실화, 연출의 특성일수 있으나 휘몰아치거나 극적인 전개는 덜해 전체적으로 잔잔하게 흘러가는 면은 있다. 한번 보고 어느정도 시간이 지나면 또 생각나게 되는 작품.
# 3,355,어중간한 액션.. 제시카 차스테인 본 걸로 위안.
# 1,구타유발자들,연개성 없는 정신병 사람들의 말도안되는 스토리. 이걸보고 재밌다고 하는 사람은 사상검증 필요함
# 5,시라노,평이 좋아서 보았는데.. 연기나 영상미는 좋았던거 같음.
# 10,의뢰인,브레드렌프로 인물이 넘 좋다.아깝다. 미인박명 왜이리 일찍 갔니?
# 7,내가 살인범이다,영화는 재밌다. 스토리, cg, 연출, 개연성 등등 조금씩 아쉽다. 잘만든 영화는 아니지만 영화를 즐기기에 무리는 없는 영화
# -----------------------------------------------------
# 8,피그,소중한 것을 잃은 후에도 아직 지키고 싶은 마음.
# 8,신비한 동물들과 덤블도어의 비밀,4편 나올런지 안나올런지 애매모호한...
# 7,오펀: 천사의 비밀,스릴러 적인 요소에서 진행은 충분히 만족할만하고 반전 또한 만족할만하다. 10년전 당시에 봤을때는 굉장히 신선했지만 시간이 지난 지금 다시보니 몇몇 아쉬움에 눈이 띔
# 9,신비한 동물들과 덤블도어의 비밀,재미있게 잘 봤음. 스토리는 약간 아쉬웠지만, 볼거리가 넘침. 장면장면들의 연출 배경 의상 전체적인 톤이 다 좋았음 . 에디레드메인은 뉴트 스캐맨더 그 자체 .
# 7,루이스 웨인: 사랑을 그린 고양이 화가,포스터와 예고에 속지말자 베네틱트 연기는 좋음
# 6,안테벨룸,인종차별을 연출로 이뤄낸 반전이 꽤 얼얼하다.
# 7,루시드 드림,우리는 꿈을 꾼다그 꿈을 다른 사람들과 공유가 가능하게 만드는 것이 바로 영화다며칠전 루시드 드림(감독-김준성, 주연-고수,설경구,2017作)이라는 영화를 봤다루시드 드림이란 수면자 스스로 꿈을 꾸고 있다는 사실을 자각한 채로 꿈을 꾸는 현상이다거기엔 디스맨이라는 꿈 공유자가 나온다 자신의 꿈속으로 들어가 문제해결의 실마리를 찾는데 그 디스맨이라는 자가 꿈속에 나타나는 것이다 그 사람은 현실생활에서는 같은 영화를 보는 사람들이 아닐까 생각한다상영되는 영화를 같이 보기 때문에 꿈(영화)의 내용을 알 수 있다우리나라에서 시도된 좀 시시한 SF영화 같다루시드 드림이라는 소재는 좀 신선했으나 CG나 줄거리 면에서 좀 약했던 것 같다기대가 커서 일까 앞으로 나아가는 중간과정이라고 생각하고, 난 오늘도 한국영화 우리 나라 영화를 사랑하고 발전되는 모습을 지켜 볼 것이다.?한국영화 파이팅!!?
# 6,신비한 동물들과 덤블도어의 비밀,해리포터 시리즈에는 미치지 못하지만 나름대로 재미있었습니다.
# 9,신비한 동물들과 덤블도어의 비밀,후기를 보니 평점이 낮고 스토리가 안좋다는 평이 많은 상태로 봤는데 솔직히 신동범보다 나았다고 생각한다. 신비한 동물 출연도 많았고.. 특히 기린이랑 전갈인지 꽃게인지 너무 웃겼다. 궁금증도 어느정도 풀렸지만 아쉬운건 내기니도 안나오고 크레덴스에 출생의 비밀이 너무 빨리 풀려서 아쉽다고 해야하나? 그런 생각이 들었다. 그래도 전체적으로 다 보고 나니 웃겼고 충격이였고 해피엔딩이였다.
# 4,신비한 동물들과 덤블도어의 비밀,스토리 진행도 너무 불친절하고 어디가 덤블도어의 비밀이란건지...동성애자인거? 아님 크레덴스가 덤블도어인거?
# -----------------------------------------------------
# 1,야차,어디서 이런 쓰래기를 만들엇냐시간 낭비햇네
# 8,더 배트맨,배트맨의 추리수사물. 4Dx 관람 추천.
# 10,위대한 쇼맨,정말 보는내내 하나도 안지루하고 너무 재밌게 봤습니다.. 기승전결 완벽하고 영화 보는 동안 온몸에 계속 소름돋아 있었어요.. 최고의 영화 정말 정말 추천합니다
# 4,신비한 동물들과 덤블도어의 비밀,해리포터 시리즈라기엔 너무 긴장감없이 뻔한 내용이었습니다. 평범한장면에 웅장한 ost가 나오거나 전투씬도 비슷비슷한 마법만 사용하거나 주인공일행이 똑같은 구도에서 똑같은 마법에 당하는 등의 장면들이 아쉬웠고, 영화 플롯이 전체적으로 너무 루즈했습니다.
# 8,이상한 나라의 수학자,가벼운 감동이 적절하니 볼만합니다
# 10,신비한 동물들과 덤블도어의 비밀,평점평에 재미없었다가 많아서 기대 없이 봤었는데, 너무 재미있었어요~웃긴 장면도 있고~ㅋㅋㅋ정말 덤블도어는 왜 결혼식에 초대를 안 했을까요?같이 들어가자고 말이라도 해주지~ㅋㅋ 다음편 얼릉 나왔으면 해요~그때는 마스크 벗고 팝콘 먹으면서 볼수있기를~^^
# 8,신비한 동물들과 덤블도어의 비밀,
# 10,야차,아무생각없이 봤다가 띵작 맞이함.너무 재밌었음!!액션 스토리라인 모두 제겐 완벽!!!다채로운 홍콩 거리 배경이 너무 잘 어울림.설경구 주연 영화는 그냥 보면됨.
# 8,레벤느망,여자만 걸리는 병. 사건을 풀어내는 방식에 고조되는 몰입감.
# 10,남자가 사랑할 때,우연히 늦은시각 교육방송에서 보게되었는데.. 너무 감명깊게 봤습니다.
# -----------------------------------------------------
# 1,스텔라,평점 알바들한테 낚였네..이런걸 돈주고ㅠㅠ
# 10,그리스도 디 오리진,감사합니다  인생을 돌아보는 시간이 됐습니다
# 7,야차,예상가능한 결말이었지만 나름 재밌었어요. 킬링타임용으로 굿~
# 10,말임씨를 부탁해,조연들의 연기가 뛰어났습니다?
# 10,항거:유관순 이야기,감사합니다 조상님들..
# 10,말임씨를 부탁해,조연배우들 명품연기  최고에요~^^
# 10,신비한 동물들과 덤블도어의 비밀,해리 포터 혼혈왕자 1부 주문,해리 포터 혼혈왕자 2부 대사가 나와서더 재밌고 소름끼쳤어요.2부 대사 always는 눈물버튼..
# 8,스펜서,조여오는 숨을 토해 살기를 희망하다.
# 9,모비우스,난 개재밌었음. 베놈같은 억지 개그 없고 모비우스 개간지남
# 2,극장판 금빛 모자이크: 땡큐!!,항마력... 그래도 인기가 있으니 나오는거겠죠?
# -----------------------------------------------------
# 10,우리가 사랑이라고 믿는 것,상실과 회복에 대하여. 배우들의 연기도 좋았고 N차 할 수록 곱씹게 된다.
# 10,루이스 웨인: 사랑을 그린 고양이 화가,배우만 보일것 같았는데 스토리와 연출에 더 빠져 재미있게 봤습니다. 연기력은 말할게 없었구요
# 6,이상한 나라의 수학자,수학을 바라보는 시선은 참신했는데 끝부분은 알파치노의 "여인의 향기"가 바로 생각남.
# 8,신비한 동물들과 덤블도어의 비밀,1편의 신비한동물과 서사를 열어가는 감동과는 다르지만, 2편을 보신경우라면 꼭 보시길 바랍니다.
# 6,모비우스,열연하는 자레드레토 잘 보았어요.
# 6,군도:민란의 시대,스케일도 크고 볼거리도 풍부했으나... 감독이 이 좋은 소재를 제대로 활용 못한 것 같다. 사회고발과 액션활극을 제대로 못 섞은 느낌. 베테랑을 보고 나니 류승완 감독이 만들었으면 더 나았겠다라는 생각이 든다.
# 10,말임씨를 부탁해,엄마랑 보러가야지햤는데 잘한선택이었던것 같아요 영화보는 중에 뭔가를 참았더니 여운이 쎄게 올라왔네요 편하게 보았지만 마음은 조금편하지않았던 그런영화였네요오랜만에 극장을 찾았는데 좋은영화를 골라서 본것같아 뿌듯하네요잘보았습니당ㅋ>ㅇ<
# 5,신비한 동물들과 덤블도어의 비밀,덤블도어의 비밀이 뭐에요..그린델왈드랑 사랑하는사이였다는거? 그건 해덕이라면 당연히 아는사실이고,, 동생이야기? 그것도 아는 사실이고.. 그냥 배우들 연기가 멋졌습니다.. 내용도 지루하고 굳이 없어도 될 장면이 너무 많아요 . 투표한다 해놓고 갑자기 기린한테 지도자를 맡기는;; ... 연기랑 귀여운 동물들 빼면 정말 실망스러운 영화..
# 10,컬러풀 웨딩즈,정말 간만에 소리내 웃으며 봤네요 특히 자매들 아버지 진짜 귀여우심
# 7,야차,돈은  들인 작품같다.주연급은 연기는  잘한다는  배우들이  잘해주었고..그밖에  조연들의  연기가  괜않았다다고봄..세트 제작에  공을  많이 들여보였고...두시간 남짓  즐겁게  봤다
# -----------------------------------------------------
# 10,세이프 하우스,라이언을 인상깊게 본 첫 영화 덴젤 워싱턴의 연기는 여전히 훌륭했다
# 1,스텔라,너무 재미없어요.. 내용도 너무 재미없구, 연기도 너무 오바스럽고 억지 감동을 끌어내려고 하고, 어디서 웃어야 할지도 모르겠고.. 남친이랑 영화데이트했는데 괜히 더 어색해졌네요.. 그만큼 너무 재미없어서 돈이 아까웠어요... ㅜㅜ 아... 그냥 돈 버린기분입니다.. 앞으론 이런 영화는... 걸러야겠어요...
# 4,신비한 동물들과 덤블도어의 비밀,이런 캐스팅으로 너무 아쉬운 스토리와 연출이네요…. ㅠ 너무 기대했나봅니다
# 1,신비한 동물들과 덤블도어의 비밀,1.재미없는 프랑스 흑백영화를 컬러로 보는 느낌2.정치적 얘기라서 꽤 지루함 3.해리포터는 마법주문이 다양해서 매력이었는데 주문도없이 지팡이만 휘둘거였으면 차라리 칼들고 싸우는게 더 나을듯 펜싱 보는것도 아니고 보는내내 화가남. 4.그렇다고 신비한 동물들도 임팩트없음딱히 감상포인트없는데 눌러야 등록이 가능하기때문에 어쩔수없이 눌렀습니다 불면증이 있으신분들께 추천합니다.
# 10,도둑들,진짜 몇 번을 봐도 너무 재밌고 멋진 영화임  스토리 연기 연출 진짜 대박 ~ 평점이 7점대인게 말이 안됌!
# 8,신비한 동물들과 덤블도어의 비밀,볼만했어요별점3개나2개나 어지간히 보는 눈이 없는건지초반에 살짝 지루하긴 한데 일단뭐 나름 갠찬아요ㅋㅋㅋㅋ유치한거 조금 들어갔지만귀여운 동물도 많이 나오고 해리포터 느낌때문 추억이 살짝돋아났어요
# 6,킹스맨: 퍼스트 에이전트,허를찌르는 대반전이 있긴함..영화마지막이 아니라 중간쯤에…영화초반부터 킹스맨의 시작은 죽은사람들의 유지를 받들어 장차 이인물로부터 시작되겠구나 생각들게끔 서사를 차곡차곡 쌓아가는것 처럼 보였으나 관객뒤통수 치기위한 감독의 훼이크…아들이 아니라 아버지였다니…ㅋㅋ유일하게 킥애스,킹스맨스런 부분이었음
# 4,신비한 동물들과 덤블도어의 비밀,
# 7,패러렐 마더스,슬픈 역사의 진실규명, 모른척 하기에 너무 강한 모성애.
# 8,사바하,근3년간 본 한국 영화중 최고
# -----------------------------------------------------
# 1,모비우스,11개를 못 줘서 아쉽다
# 9,신비한 동물들과 덤블도어의 비밀,
# 10,효자,펑펑 웃고 울었습니다.연기도 좋구 스토리도 좋아요강추
# 1,마이 파더,토막살인범을 이렇게 미화해서 감성팔이하니까 좋냐? 쓰레기 감독
# 6,신비한 동물들과 덤블도어의 비밀,CG와 영상미는 좋았지만 캐릭터의 스토리 서사가 아쉬웠다2편이 3편에 대한 예고편같은 느낌이였다면 3편도 4편에 대한 예고편인것 갵은 느낌임신캐릭터는 나오는데 캐릭터의 깊이가 없고 떡밥만 뿌림
# 1,야차,역대급 망작 이네요ㅡㅡ;
# 10,태어나길 잘했어,재미와 감동최고입니다.
# 8,바바리안,여운은 남으나, 뭔가 조금 애매하게 끝나는 느낌
# 2,스텔라,개인적으로 나는 최악  손호준 혼자 북치고 장구치는 영화 . 재미도 없고 그냥 애쓰는게 보여서 짠했음
# 10,호텔 뭄바이,
# -----------------------------------------------------
# 2,신비한 동물들과 덤블도어의 비밀,이렇게 잠오는 영화는 처음이다....동물들 진짜 조금 나오고 나머지 스토리들은 쓸대없이 길어요
# 2,스텔라,억지 웃음, 억지 감동, 억지 억지 배우들의 연기만 볼만하고 보면서 뭘 말하고 싶은지 설정이 다 어색했어요..왠만하면 평점 안다는데 한국영화 발전을 위해 씁니다 ㅠㅠ요즘 같은 시국에 영화 보러가는거 쉽지 않은데편하게 웃을 수 있는 영화가 보고싶네요
# 9,신비한 동물들과 덤블도어의 비밀,처음에 좀 지루한면이 있었지만 명불허전이네요 ㅎ
# 10,멜랑콜리아,공감하기 위해 끝까지 엔딩 크레딧을 보게 만든 인생 첫 영화
# 9,우나기,죄책감에 과거에서 헤어나오지 못하는 야마시타와, 알을 낳기 위해 먼 여행을 떠나는 우나기 이야기가 대비된다. 소동 이후 장어를 놓아주며 '나도 이제 너와 같아졌다'고 말하는 순간은 그가 마음의 족쇄에서 해방된 순간일테다.
# 8,수퍼 소닉2,게임의 실사화를 멋지게 해냈다. 로보트닉 악당역의 짐캐리 연기가 최고
# 10,레모니 스니켓의 위험한 대결,초 6인데 재밌게 보고 있어요!!
# 2,그날, 바다,수상한점의 규명보단 추리와 추상적 결론이네요
# 10,신비한 동물들과 덤블도어의 비밀,해리포터와 다른 시리즈라는 것을 받아들이고 본다면 재미를 찾을 수 있다. 신동사는 해리포터가 아니다.
# 10,클래식,삶의 고통과 허무에 지친 사람들에게 청춘의 기쁨을 선사해주는 작품.이런 사랑 하진 못했지만 꿈꿀 순 있으니..
# -----------------------------------------------------
# 7,채피,완성도는 떨어지지만 톡톡튀는 개성에 마법처럼 빛나는 순간이 존재한다
# 8,신비한 동물들과 덤블도어의 비밀,스토리는 리뷰 적혀 있는 듯이 별 내용이 없음. 4년만에 온건데 너무 하지 않나 싶었음. 근데 뭐 그냥 볼만은 했다.. 기대안하고 보면 괜찮아요. 신동사에서 호그와트랑 교수님들 보이니 뭔가 기분 좋았당
# 8,프리즈너스,이 스릴을 느껴본지가 언제인지 그립다
# 1,윈드폴,와 시간낭비했네 정말 역대급 뻘 영화...
# 10,더티 댄싱,내가 가장 좋아하는 영화 1위최고의 스토리 와 영상
# 7,레미제라블,영상미 좋은 뮤지컬 한편 본 기분입니다
# 4,벽 속에 숨은 마법시계,꼬맹이 너무 답답함; 지가잘못해놓고 실수엿다? 뭐래
# 10,스텔라,호주니 좋았음 억지  웃음만 빼면 스토리는 좋았음
# 1,동네사람들,보지마세요... 제발...
# 8,사랑에 빠진 것처럼,몰입감은 어느정도 있는 영화이고 등장인물 전체가 그게 진짜 사랑인줄알고 사랑에 겉도는 행동을 한다.나름 사랑에 대해 생각해 볼 문제.
# -----------------------------------------------------
# 4,신비한 동물들과 덤블도어의 비밀,최악의 동물 사전...기억에 남는건 덤블도어 게이
# 5,사랑은 비가 갠 뒤처럼,각자의 이유로 꿈을 잃고 살아가는 두 사람이, 나이도 다르고 배경도 다르고 사고방식도 다른 서로에게서 세대를 초월하는 동지 의식을 공유하면서 상대방을 통해 내 안의 에너지를 다시 살리고는 결국에는 다시 자기만의 꿈을 되찾는다는 뻔하고 진부하고 그저 그런 이야기. 별로 극적인 내용도 없고 절실한 감정 교류도 없고 아슬아슬한 로맨스도 없고. 그저 '나는 내일 어제의 너와 만난다'의 여주인공을 다시 봤다는 것에 만족한다.
# 10,청년경찰,다시 봐도 재밌어요ㅋㅋ 연기 액션 스피드 다 좋아ㅋㅋㅋㅋ 투! 안만드나요~ㅠㅠ?
# 9,맨 인 더 다크 2 ,아이랑 개가 ...  제일 불쌍 ㅠㅠ
# 5,신비한 동물들과 덤블도어의 비밀,이젠 동물들이 안나오는  동물사전 시리즈 영화
# 10,루이스 웨인: 사랑을 그린 고양이 화가,
# 6,신비한 동물들과 덤블도어의 비밀,신비한동물사전은 후추랑 소금 정도고 덤블도어 사랑이야기가 주된 이야기 동물 이야기는 다 합쳐도 15분 안될듯
# 10,말임씨를 부탁해,김영옥 배우님의 멋진 연기와 따뜻하고 뭉클했던 이야기.. !
# 10,브로크백 마운틴,이런 영화를 다시 볼 수 있을지 모르겠다
# 1,스텔라,호준이한테는 미안하지만 영화쪽으로 믿고 거르는 과학...호준아 그냥 삼시세끼나 찍자 솔직히 너도 알지 않니 .. 너가 영화쪽에서 먹히는 급은 아니자나...생계가 궁핍해서 푼돈이라도 받으려고 찍는거면 할말 없다만 그게 아니라면 적당히 하자 흑역사만 늘어날뿐이야...
# -----------------------------------------------------
# 10,조제,버릴 것 없는 영상과 음악들. 실제 영석이가 아닐까 싶던 역할 그대로인 연기두고두고 보고싶은 작품
# 10,뱅드림! 팝핀' 드림!,제가 카스미 팬인데 못볼까봐 조마조마했는데다행히 이웃동네인 수원시에서 상영을해서 간신히 보고 있습니다.
# 10,퍼펙트 게임,야구팬이라면 꼭 봐야할 영화
# 6,신이 말하는 대로,원작이 재밌는데 영화로 짬뽕시키니까 이도저도 아닌 데스게임이 되어버렸음 그냥 자극적이었다 라는 말 밖에 안나옴
# 9,루이스 웨인: 사랑을 그린 고양이 화가,해피엔딩이면서 세드엔딩인듯하다
# 10,코코,영화 잘봤습니다^^ 감동적이네요
# 10,야차,
# 8,해피 투게더,우리 다시 시작할까, 라는 대사가 대단하다
# 10,신비한 동물들과 덤블도어의 비밀,ㅋㅋㅋ 전갈댄스출때는 다같이 웃었댜
# 10,야차,
# -----------------------------------------------------
# 1,파일럿: 배틀 포 서바이벌,이 영화 수익금은 우크라이나 전쟁터로 빠져나갑니다.
# 8,스텔라,넋놓고 보게 된다 재밌다
# 7,프레스티지,조금은 뻔한 속임수라도 박수는 쳐야지.
# 10,도둑들,평점이 너무 낮네 ;;; 지루한 부분없이 잼나게 봄.
# 7,진링의 13소녀,우리는 어떻게 되었는지 알기에
# 10,윈드폴,평점 너무 낮아서 조금 올립니다.나름의 유머포인트가 본인에게 맞으면 괜찮은 영화라 생각해요.반전도 있고 유치하지 안아요. 느리지만 안정적인 전개도 개인적으로 좋았습니다.
# 4,마담 싸이코,뻔한내용. 굳이 시간써가며 볼 가치는 없다고 생각
# 10,클레멘타인,영상미와 연기력, 스토리 OST, 연출 어느하나 빠질데없는 불세출의 명작
# 10,장화, 홍련,엔딩크레딧 올라갈때 혼자 강가에 앉아있는 수미의 모습이 잊혀지지 않는다
# 6,봄날은 간다,라면이 말합니다.<왜 나를 두고 이상한 상상하는거요?> 자동차가 말합니다.<니가 성질 난다고 나를 긁냐?>. 영상미는 높이 평가해야.
# -----------------------------------------------------
# 1,더 배트맨,유치...엄청 우울하고 다크하다했는데 걍 화면만 어두울뿐 뻔하고 유치하다
# 9,노바디 ,우크라이나인이 보면 좋아 할 만한 영화. 킬링타임용보단 조금 더 잼있음! 마지막 담배피는 장면이 모든걸 말해줌! 볼만한 액션영화!
# 4,야차,구라 안치고 불한당이 열배는 더 재밌음
# 2,야차,
# 8,더 배트맨,새로운배트맨이다
# 10,그것만이 내 세상,감동 연출 연기 다 잡은 작품 감동을 쥐어 짜지않고 재치있게 보여줘서 좋았다
# 8,아메리칸 싸이코,욕망, 자본, 살인
# 2,신비한 동물들과 덤블도어의 비밀,덤블도어의 비밀 개하찮네
# 10,인터스텔라,지금봐도 전혀 어색함이 없는 울림이 깊은 영화  이건 어쩌면 다가오는 미래
# 8,듄,본 내용 시작하자마자 끝난 느낌...
# -----------------------------------------------------
# 10,덕혜옹주,손예진 배우 연기는 말할것도 없고 스토리 전개도 좋았음
# 8,특송,볼만하다 그럭저럭 액션도 좋고
# 9,마음에 부는 바람,매디슨 카운티의 다리가 오버랩 되었다.
# 7,수퍼 소닉2,재미있게 잘봤습니다
# 8,앰뷸런스,재미있게 잘봤습니다
# 6,신비한 동물들과 덤블도어의 비밀,덤블도어의 과거가 심도 깊게 표현을 해주기를 바랬는데, 비주얼에 더 신경을 쓴 듯 합니다.
# 1,인민을 위해 복무하라,헐 김복남 감독님이라니 믿을수가 없다 사단장이랑 본부인, 각자의 자식들만 불쌍함 무슨 밑도 끝도 없이 옷 벗어! 하더니 사랑에 빠지고 천년의 사랑인척ㅋㅋ 시간만 날렸네ㅠ
# 1,하로동선,이명박 박근혜를 우상화해 영화화한다면 아주 개 염병을떨겠지자살 사망으로 사건 종결난걸로 무죄다 떠벌리지마라 이사람 그리 대단하지 않았다
# 8,블랙 크랩,왜 재미없다고 하는지 이해가 안됨. 오랜만에 끝까지 본 넷플 영환데
# 8,태어나길 잘했어,올해의 힐링시네마
# -----------------------------------------------------

# %%
print(reviews[0].contents)
# Out:
# ['\n', <a class="movie color_b" href="?st=mcode&amp;sword=94767&amp;target=after">덕혜옹주</a>, '\n', <div class="list_netizen_score">
# <span class="st_off"><span class="st_on" style="width:100%">별점 - 총 10점 중</span></span><em>10</em>
# </div>, '\n', <br/>, '손예진 배우 연기는 말할것도 없고 스토리 전개도 좋았음 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t', <a class="report" href="#" onclick="report('rlag****', '+vxpiGTVLXb/U3A2+bYp4SFVsKc08PY747vxkyUkGYw=', '손예진 배우 연기는 말할것도 없고 스토리 전개도 좋았음', '18032971', 'point_after');" style="color:#8F8F8F" title="새 창">신고</a>, '\n']

# %%
import requests
from bs4 import BeautifulSoup
title = []
link = []
urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
bookList = bs.select('a.gd_name')

for bookDom in bookList:
    title.append(bookDom.string)
    link.append(bookDom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
with open('output/booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '혼자 공부하는 파이썬', '혼자 공부하는 머신러닝+딥러닝', '1일 1로그 100일 완성 IT 지식', '만들면서 배우는 파이썬과 40개의 작품들', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', 'Black Hat Python 2/e', '핸즈온 머신러닝', '밑바닥부터 시작하는 딥러닝 ', '파이썬 머신러닝 완벽 가이드', '배워서 바로 써먹는 데이터 분석 with 파이썬', '파이썬 알고리즘 인터뷰', '두근두근 파이썬', 'Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편', '파이썬을 이용한 통계분석', '모두의 데이터 분석 with 파이썬', 'Do it! 파이썬 생활 프로그래밍', '파이썬 for Beginner', '파이썬을 이용한 딥러닝/강화학습 주식투자', 'Do it! 첫 파이썬', '파워 유저를 위한 파이썬 EXPRESS', 'Do it! 첫 코딩 with 파이썬', '모두의 파이썬', '암호화폐 자동매매 시스템 만들기 with 파이썬']
# -- 도서 링크 URL --
# ['/Product/Goods/74419916', '/Product/Goods/74269975', '/Product/Goods/96024871', '/Product/Goods/105803863', '/Product/Goods/107490270', '/Product/Goods/91433923', '/Product/Goods/108802330', '/Product/Goods/89959711', '/Product/Goods/34970929', '/Product/Goods/108824557', '/Product/Goods/108787259', '/Product/Goods/91084402', '/Product/Goods/35279965', '/Product/Goods/91219874', '/Product/Goods/108851761', '/Product/Goods/72227684', '/Product/Goods/91437485', '/Product/Goods/105673484', '/Product/Goods/108251432', '/Product/Goods/89904189', '/Product/Goods/95784557', '/Product/Goods/96580456', '/Product/Goods/66531799', '/Product/Goods/107635612']

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename = "C:/Temp/forecast.xml"
req.urlretrieve(url, savename)

xml = open(savename, "r", encoding="utf-8").read()
soup = BeautifulSoup(xml, 'html.parser') # lxml

info = {}
for location in soup.find_all("location"):
    loc = location.find('city').string
    min_w = location.find_all('tmn')
    max_w = location.find_all('tmx')
    weather = [a.string+"~"+b.string for a, b in zip(min_w, max_w)]

    if not (loc in info):
        info[loc] = []
    for data in weather:
        info[loc].append(data)
print(info)

with open('C:/Temp/forecast.txt', "wt", encoding="utf-8") as f:
    for loc in sorted(info.keys()):
        f.write(str(loc)+'\n')
        for name in info[loc]:
            f.write('\t'+str(name)+'\n')

# %%
import json
import urllib.request

#User-Agent를 조작하는 경우 
hdr = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) '+ 
        'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.80 Safari/537.36'}

req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php', headers = hdr)
#req = urllib.request.Request('http://unico2013.dothome.co.kr/crawling/header.php')
data = urllib.request.urlopen(req).read()
print(data)
page = data.decode('utf-8', 'ignore')
print(page)
res_content = json.loads(data)

print(res_content["result"])
